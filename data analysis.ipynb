# %%
# Analyzing Data with Pandas and Visualizing Results with Matplotlib

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# Set Seaborn style for prettier plots
sns.set(style="whitegrid")

#Task 1: Load and Explore the Dataset

try:
    # Load dataset: Iris is available directly from scikit-learn
    iris = load_iris(as_frame=True)
    df = iris.frame  # Convert to pandas DataFrame
    
    # Add target (species) to the DataFrame
    df['species'] = iris.target_names[iris.target]

    # Context note:
    # Iris is a classic dataset available in the UCI Machine Learning Repository,
    # widely used for data analysis and ML practice.
    # Reference: https://archive.ics.uci.edu/

    # Display first few rows
    print("Preview of the dataset:")
    print(df.head())

    # Check datatypes and missing values
    print("\nData types and null values:")
    print(df.info())
    print("\nMissing values per column:")
    print(df.isnull().sum())

    # Cleaning: (no missing values here, but example handling shown)
    df = df.dropna()

except FileNotFoundError:
    print("❌ Error: Dataset file not found.")
except Exception as e:
    print(f"⚠️ Unexpected error: {e}")

#  Basic Data Analysis

# Statistical summary of numerical columns
print("\nBasic statistics of numerical columns:")
print(df.describe())

# Group by species and calculate mean of features
print("\nAverage feature values per species:")
print(df.groupby('species').mean())

# Task 3: Data Visualization

# Line Chart: Example using cumulative sepal length as a time series-like trend
plt.figure(figsize=(8,5))
df['sepal length (cm)'].cumsum().plot()
plt.title("Line Chart: Cumulative Sepal Lengths")
plt.xlabel("Index")
plt.ylabel("Cumulative Sepal Length (cm)")
plt.show()

# Bar Chart: Average petal length per species
plt.figure(figsize=(8,5))
df.groupby('species')['petal length (cm)'].mean().plot(kind='bar', color=['skyblue','lightgreen','salmon'])
plt.title("Bar Chart: Avg Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.show()

# Histogram: Distribution of sepal width
plt.figure(figsize=(8,5))
plt.hist(df['sepal width (cm)'], bins=15, color='purple', alpha=0.7)
plt.title("Histogram: Sepal Width Distribution")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# Scatter Plot: Sepal length vs Petal length, colored by species
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='species', palette='Set2')
plt.title("Scatter Plot: Sepal Length vs Petal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend(title="Species")
plt.show()


# - Iris Setosa has distinctly smaller petal lengths compared to other species.
# - Sepal width distribution shows most values are between 2.5–3.5 cm.
# - Scatter plot highlights clear species separation based on petal and sepal measurements.
# Out:
# Preview of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa
#
# Data types and null values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
# ...
